# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno

# %%
Energydata = pd.read_csv (r"C:\Users\Oluwarogbayimika\Desktop\EXCEL DATA ANALYTICS\TRAINING\accidents MAY\all_energy_statistics.csv")

# %%
Energydata
# Out:
#         country_or_area                commodity_transaction  year  \
# 0               Austria   Additives and Oxygenates - Exports  1996
# 1               Austria   Additives and Oxygenates - Exports  1995
# 2               Belgium   Additives and Oxygenates - Exports  2014
# 3               Belgium   Additives and Oxygenates - Exports  2013
# 4               Belgium   Additives and Oxygenates - Exports  2012
# ...                 ...                                  ...   ...
# 1189477        Viet Nam  Electricity - total wind production  2012
# 1189478        Viet Nam  Electricity - total wind production  2011
# 1189479        Viet Nam  Electricity - total wind production  2010
# 1189480        Viet Nam  Electricity - total wind production  2009
# 1189481        Viet Nam  Electricity - total wind production  2008
#
#                             unit  quantity  quantity_footnotes  \
# 0         Metric tons,  thousand       5.0                 NaN
# ...

# %%
Energydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1189482 entries, 0 to 1189481
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   country_or_area        1189482 non-null  object
#  1   commodity_transaction  1189482 non-null  object
#  2   year                   1189482 non-null  int64
#  3   unit                   1189482 non-null  object
#  4   quantity               1189482 non-null  float64
#  5   quantity_footnotes     163946 non-null   float64
#  6   category               1189482 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 63.5+ MB

# %%
Country = Energydata.country_or_area

# %%
len (Country)
# Out:
# 1189482

# %%
Energydata.shape #Check for the number of rows and columns in the dataset
# Out:
# (1189482, 7)

# %%
print("The names of the countries present are:{}".format(Country.unique()))
# Out:
# The names of the countries present are:['Austria' 'Belgium' 'Czechia' 'Finland' 'France' 'Greece' 'Hungary'
#  'Italy' 'Korea, Republic of' 'Netherlands' 'Romania' 'Serbia' 'Slovakia'
#  'Ukraine' 'United Kingdom' 'United States' 'Brunei Darussalam' 'Bulgaria'
#  'Canada' 'Chile' 'Croatia' 'Iran (Islamic Rep. of)' 'Jordan' 'Lithuania'
#  'Mexico' 'Oman' 'Other Asia' 'Poland' 'Portugal' 'Spain' 'Sweden'
#  'Switzerland' 'T.F.Yug.Rep. Macedonia' 'Turkey' 'Uzbekistan' 'Argentina'
#  'Colombia' 'Germany' 'Norway' 'Australia' 'China, Macao SAR' 'Japan'
#  'Denmark' 'Ireland' 'Philippines' 'Bangladesh' 'Eritrea' 'Ethiopia'
#  'Lesotho' 'Nepal' 'Niger' 'Pakistan' 'Serbia and Montenegro' 'Tunisia'
#  'Botswana' 'Georgia' 'Republic of Moldova' 'Peru' 'South Africa'
#  'Iceland' 'Latvia' 'Luxembourg' 'Cuba' 'Kyrgyzstan' 'Singapore'
#  'Thailand' 'United Arab Emirates' 'Uruguay' 'Armenia' 'Fiji'
#  "Korea, Dem.Ppl's.Rep." 'Russian Federation' 'Swaziland' 'Zimbabwe'
# ...

# %%
keywordg7 = ['Canada', 'United States', 'United Kingdom', 'Japan','France','Italy', 'Germany']
#Assign all the g7countries to a particular variable

# %%
keywordg7
# Out:
# ['Canada',
#  'United States',
#  'United Kingdom',
#  'Japan',
#  'France',
#  'Italy',
#  'Germany']

# %%
g7_data = Energydata[Energydata['country_or_area'].isin(keywordg7)]

# %%
g7_data
# Out:
#         country_or_area                commodity_transaction  year  \
# 26               France   Additives and Oxygenates - Exports  2014
# 27               France   Additives and Oxygenates - Exports  2013
# 28               France   Additives and Oxygenates - Exports  2012
# 29               France   Additives and Oxygenates - Exports  2011
# 30               France   Additives and Oxygenates - Exports  2010
# ...                 ...                                  ...   ...
# 1189456   United States  Electricity - total wind production  1994
# 1189457   United States  Electricity - total wind production  1993
# 1189458   United States  Electricity - total wind production  1992
# 1189459   United States  Electricity - total wind production  1991
# 1189460   United States  Electricity - total wind production  1990
#
#                             unit  quantity  quantity_footnotes  \
# 26        Metric tons,  thousand     119.0                 NaN
# ...

# %%
G7 = pd.DataFrame(g7_data)  #Create a dataframe of all g7countries

# %%
G7
# Out:
#         country_or_area                commodity_transaction  year  \
# 26               France   Additives and Oxygenates - Exports  2014
# 27               France   Additives and Oxygenates - Exports  2013
# 28               France   Additives and Oxygenates - Exports  2012
# 29               France   Additives and Oxygenates - Exports  2011
# 30               France   Additives and Oxygenates - Exports  2010
# ...                 ...                                  ...   ...
# 1189456   United States  Electricity - total wind production  1994
# 1189457   United States  Electricity - total wind production  1993
# 1189458   United States  Electricity - total wind production  1992
# 1189459   United States  Electricity - total wind production  1991
# 1189460   United States  Electricity - total wind production  1990
#
#                             unit  quantity  quantity_footnotes  \
# 26        Metric tons,  thousand     119.0                 NaN
# ...

# %%
keywordA7 = ['Nigeria', 'Algeria', 'Egypt', 'Ethopia', 'Morocco', 'South Africa', 'Angola']

# %%
keywordA7
# Out:
# ['Nigeria', 'Algeria', 'Egypt', 'Ethopia', 'Morocco', 'South Africa', 'Angola']

# %%
A7_data = Energydata[Energydata['country_or_area'].isin(keywordA7)]

# %%
A7_data
# Out:
#         country_or_area                              commodity_transaction  \
# 5056       South Africa  Anthracite - consumption by chemical and petro...
# 5057       South Africa  Anthracite - consumption by chemical and petro...
# 5058       South Africa  Anthracite - consumption by chemical and petro...
# 5059       South Africa  Anthracite - consumption by chemical and petro...
# 5349       South Africa         Anthracite - consumption by iron and steel
# ...                 ...                                                ...
# 1189224    South Africa                Electricity - total wind production
# 1189225    South Africa                Electricity - total wind production
# 1189226    South Africa                Electricity - total wind production
# 1189227    South Africa                Electricity - total wind production
# 1189228    South Africa                Electricity - total wind production
#
# ...

# %%
A7 = pd.DataFrame(A7_data)

# %%
A7
# Out:
#         country_or_area                              commodity_transaction  \
# 5056       South Africa  Anthracite - consumption by chemical and petro...
# 5057       South Africa  Anthracite - consumption by chemical and petro...
# 5058       South Africa  Anthracite - consumption by chemical and petro...
# 5059       South Africa  Anthracite - consumption by chemical and petro...
# 5349       South Africa         Anthracite - consumption by iron and steel
# ...                 ...                                                ...
# 1189224    South Africa                Electricity - total wind production
# 1189225    South Africa                Electricity - total wind production
# 1189226    South Africa                Electricity - total wind production
# 1189227    South Africa                Electricity - total wind production
# 1189228    South Africa                Electricity - total wind production
#
# ...

# %%
G7
# Out:
#         country_or_area                commodity_transaction  year  \
# 26               France   Additives and Oxygenates - Exports  2014
# 27               France   Additives and Oxygenates - Exports  2013
# 28               France   Additives and Oxygenates - Exports  2012
# 29               France   Additives and Oxygenates - Exports  2011
# 30               France   Additives and Oxygenates - Exports  2010
# ...                 ...                                  ...   ...
# 1189456   United States  Electricity - total wind production  1994
# 1189457   United States  Electricity - total wind production  1993
# 1189458   United States  Electricity - total wind production  1992
# 1189459   United States  Electricity - total wind production  1991
# 1189460   United States  Electricity - total wind production  1990
#
#                             unit  quantity  quantity_footnotes  \
# 26        Metric tons,  thousand     119.0                 NaN
# ...

# %% [markdown]
# ### DATA EXPLORATION AND CLEANING FOR  G7 COUNTRIES

# %%
G7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121843 entries, 26 to 1189460
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country_or_area        121843 non-null  object
#  1   commodity_transaction  121843 non-null  object
#  2   year                   121843 non-null  int64
#  3   unit                   121843 non-null  object
#  4   quantity               121843 non-null  float64
#  5   quantity_footnotes     4329 non-null    float64
#  6   category               121843 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 7.4+ MB

# %% [markdown]
# ###### FROM THE RESULT ABOVE IT LOOKS LIKE A TON OF DATA IS MISSING FROM quantity_footnotes.

# %%
len(G7['country_or_area'].unique())  #unique values for country
# Out:
# 7

# %%
len(G7['year'].unique())  #unique values for year
# Out:
# 25

# %%
len(G7['unit'].unique())   #unique values for unit
# Out:
# 6

# %%
len(G7['quantity'].unique()) #unique values for quantity
# Out:
# 34652

# %% [markdown]
# CHECKING FOR MISSING VALUES IN THE QUANTITY_FOOTNOTES COLUMN AND FINDING IF ITS VALUABLE FOR OUR ANALYSIS

# %%
 G7.isnull().sum()
# Out:
# country_or_area               0
# commodity_transaction         0
# year                          0
# unit                          0
# quantity                      0
# quantity_footnotes       117514
# category                      0
# dtype: int64

# %%
values_missing = pd.concat([G7.isnull().sum(), 100 * G7.isnull().mean()], axis = 1)

# %%
values_missing
# Out:
#                             0          1
# country_or_area             0   0.000000
# commodity_transaction       0   0.000000
# year                        0   0.000000
# unit                        0   0.000000
# quantity                    0   0.000000
# quantity_footnotes     117514  96.447067
# category                    0   0.000000

# %%
values_missing.columns = ("Count", 'Percentage %')

# %%
values_missing
# Out:
#                         Count  Percentage %
# country_or_area             0      0.000000
# commodity_transaction       0      0.000000
# year                        0      0.000000
# unit                        0      0.000000
# quantity                    0      0.000000
# quantity_footnotes     117514     96.447067
# category                    0      0.000000

# %% [markdown]
# ## 117514 quantity_footnotes values are missing with 96.447067%

# %%
#CHECKING FOR THE MISSINGNESS RATE
msno.matrix(G7)
# Out:
# <Axes: >

# %%
##SINCE THE COLUMN (QUANTITY_FOOTNOTES) HAS ALOT OF MISSING VALUES, IT NEEDS TO BE DROPPED FOR ACCURATE ANALYSIS

DROP_G7 = G7.drop(["quantity_footnotes"], axis = 1)

# %%
DROP_G7      #new dataframe with dropped column
# Out:
#         country_or_area                commodity_transaction  year  \
# 26               France   Additives and Oxygenates - Exports  2014
# 27               France   Additives and Oxygenates - Exports  2013
# 28               France   Additives and Oxygenates - Exports  2012
# 29               France   Additives and Oxygenates - Exports  2011
# 30               France   Additives and Oxygenates - Exports  2010
# ...                 ...                                  ...   ...
# 1189456   United States  Electricity - total wind production  1994
# 1189457   United States  Electricity - total wind production  1993
# 1189458   United States  Electricity - total wind production  1992
# 1189459   United States  Electricity - total wind production  1991
# 1189460   United States  Electricity - total wind production  1990
#
#                             unit  quantity                  category
# 26        Metric tons,  thousand     119.0  additives_and_oxygenates
# ...

# %% [markdown]
# ## FURTHER DATA  CLEANING PROCESSES USING NEW DROP_G7 DATAFRAME

# %%
#CONVERTING ALL NAMES IN THE DATAFRAME TO LOWER CASE TO AVOID ANY ISSUES IN FUTURE ANALYSIS

DROP_G7.country_or_area = DROP_G7.country_or_area.str.lower()
DROP_G7.commodity_transaction = DROP_G7.commodity_transaction.str.lower()
DROP_G7.unit = DROP_G7.unit.str.lower()
DROP_G7.category = DROP_G7.category.str.lower()

# %%
DROP_G7
# Out:
#         country_or_area                commodity_transaction  year  \
# 26               france   additives and oxygenates - exports  2014
# 27               france   additives and oxygenates - exports  2013
# 28               france   additives and oxygenates - exports  2012
# 29               france   additives and oxygenates - exports  2011
# 30               france   additives and oxygenates - exports  2010
# ...                 ...                                  ...   ...
# 1189456   united states  electricity - total wind production  1994
# 1189457   united states  electricity - total wind production  1993
# 1189458   united states  electricity - total wind production  1992
# 1189459   united states  electricity - total wind production  1991
# 1189460   united states  electricity - total wind production  1990
#
#                             unit  quantity                  category
# 26        metric tons,  thousand     119.0  additives_and_oxygenates
# ...

# %%
DROP_G7.country_or_area.unique() #crosschecking data contains all countries in G7 category
# Out:
# array(['france', 'italy', 'united kingdom', 'united states', 'canada',
#        'germany', 'japan'], dtype=object)

# %%
DROP_G7.year.unique() #crosschecking data contains all years between 1990-2014
# Out:
# array([2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004,
#        2003, 2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993,
#        1992, 1991, 1990], dtype=int64)

# %%
DROP_G7.category.unique()
# Out:
# array(['additives_and_oxygenates', 'animal_waste', 'anthracite',
#        'aviation_gasoline', 'bagasse', 'biodiesel', 'biogases',
#        'biogasoline', 'bitumen', 'black_liquor', 'blast_furnace_gas',
#        'brown_coal_briquettes', 'brown_coal', 'charcoal', 'coal_tar',
#        'coke_oven_coke', 'coking_coal', 'conventional_crude_oil',
#        'direct_use_of_geothermal_heat',
#        'direct_use_of_solar_thermal_heat',
#        'electricity_net_installed_capacity_of_electric_power_plants',
#        'ethane', 'falling_water', 'fuel_oil', 'fuelwood',
#        'gas_oil_diesel_oil', 'gasoline_type_jet_fuel', 'gasworks_gas',
#        'geothermal', 'hard_coal', 'heat', 'hydro', 'industrial_waste',
#        'kerosene_type_jet_fuel', 'lignite', 'liquified_petroleum_gas',
#        'lubricants', 'motor_gasoline', 'municipal_wastes', 'naphtha',
#        'natural_gas_including_lng', 'natural_gas_liquids',
#        'nuclear_electricity', 'of_which_biodiesel',
# ...

# %%
unique_commodities = DROP_G7.commodity_transaction.unique()

unique_commodities
# Out:
# array(['additives and oxygenates - exports',
#        'additives and oxygenates - imports',
#        'additives and oxygenates - production', ...,
#        'white spirit and special boiling point industrial spirits - transformation',
#        'white spirit and special boiling point industrial spirits - transformation in petrochemical plants',
#        'electricity - total wind production'], dtype=object)

# %%
DROP_G7.isnull().sum()
# Out:
# country_or_area          0
# commodity_transaction    0
# year                     0
# unit                     0
# quantity                 0
# category                 0
# dtype: int64

# %%
df = pd.DataFrame({"unique_comm": unique_commodities})

# %%
crudeoil = df[df.unique_comm.str.contains("electricity", case = False)]

# %%
crudeoil.unique_comm.unique()  #FROM THE OUTPUT, THERE ARE VARIOUS CRUDE OIL GROUPINGS, HENCE, PRODUCTION, EXPORTS AND IMPORTS WILL BE CONSIDERED IN THE ANALYSIS
# Out:
# array(['animal waste - transformation in electricity, chp and heat plants',
#        'anthracite - transformation in electricity, chp and heat plants',
#        'anthracite - transformation in electricity plants - main activity producers',
#        'biodiesel - transformation in electricity, chp and heat plants',
#        'biodiesel - transformation in electricity plants - main activity producers',
#        'biogases - own use by electricity, chp and heat plants',
#        'biogases - transformation in electricity, chp and heat plants',
#        'biogases - transformation in electricity plants - autoproducers',
#        'biogases - transformation in electricity plants - main activity producers',
#        'bitumen - transformation in electricity, chp and heat plants',
#        'bitumen - transformation in electricity plants - autoproducers',
#        'bitumen - transformation in electricity plants - main activity producers',
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS
#
# ## CRUDE OIL PRODUCTION IN G7 COUNTRIES
#
# #### 1.0 COUNTRY DATA CATEGORIZATION

# %%
#CREATING A FUNCTION THAT CAN BE USED TO EXTRACT  DATA FROM A PARTICULAR G7 COUNTRY) 

def choose_country (country_name):
    country_data = DROP_G7[DROP_G7.country_or_area.isin(country_name)].sort_values("year").reset_index()
    country_data.drop ('index', axis=1 , inplace = True)
    return  country_data

# %%
# GENERATING AND ASSIGNING DATA TO EACH COUNTRY IN G7

france_data = choose_country (["france"])
japan_data = choose_country (["japan"])
uk_data = choose_country (["united kingdom"])
us_data = choose_country (["united states"])
germany_data = choose_country (["germany"])
italy_data = choose_country (["italy"])
canada_data = choose_country (["canada"])

# %%
france_data
# Out:
#       country_or_area                              commodity_transaction  \
# 0              france                          black liquor - production
# 1              france                other oil products n.e.c. - imports
# 2              france              hard coal - consumption by households
# 3              france  black liquor - consumption by other manuf., co...
# 4              france  other oil products n.e.c. - final energy consu...
# ...               ...                                                ...
# 17231          france                               hydro – autoproducer
# 17232          france           vegetal waste - final energy consumption
# 17233          france                                  bitumen - exports
# 17234          france                 lignite - final energy consumption
# 17235          france                 additives and oxygenates - exports
#
#        year                     unit  quantity  \
# ...

# %% [markdown]
# #### 2.0 CRUDE OIL DATA CATEGORIZATION BASED ON COUNTRY

# %%
#CREATING ANOTHER FUNCTION THAT CAN BE USED TO EXTRACT CATEGORY DATA FROM A PARTICULAR G7 COUNTRY) 

def choose_category (country_data, category_name):
    category_data = country_data[country_data.category.isin(category_name)].sort_values("year").reset_index()
    category_data.drop ('index', axis=1 , inplace = True)
    return  category_data

# %%
france_crude = choose_category (france_data,["conventional_crude_oil"])
japan_crude = choose_category (japan_data,["conventional_crude_oil"])
uk_crude = choose_category (uk_data,["conventional_crude_oil"])
us_crude = choose_category (us_data,["conventional_crude_oil"])
germany_crude = choose_category (germany_data,["conventional_crude_oil"])
italy_crude = choose_category (italy_data,["conventional_crude_oil"])
canada_crude = choose_category (canada_data,["conventional_crude_oil"])

# %%
france_crude
# Out:
#     country_or_area                              commodity_transaction  year  \
# 0            france       conventional crude oil - total energy supply  1990
# 1            france            conventional crude oil - transformation  1990
# 2            france             conventional crude oil - stock changes  1990
# 3            france  conventional crude oil - transformation in oil...  1990
# 4            france                conventional crude oil - production  1990
# ..              ...                                                ...   ...
# 204          france                   conventional crude oil - exports  2014
# 205          france                crude petroleum - refinery capacity  2014
# 206          france                         crude petroleum - reserves  2014
# 207          france            conventional crude oil - transformation  2014
# 208          france  conventional crude oil - transformation in oil...  2014
#
# ...

# %% [markdown]
# ### 2.0.1 FURTHER FILTERING INTO CRUDEOIL PRODUCTION

# %%
def choose_commodity (category_data, commodity_name):
    commodity_data = category_data[category_data.commodity_transaction.isin(commodity_name)].sort_values("year").reset_index()
    commodity_data.drop ('index', axis=1 , inplace = True)
    return  commodity_data

# %%
france_crude_prod = choose_commodity (france_crude, ["conventional crude oil - production"])
japan_crude_prod = choose_commodity (japan_crude, ["conventional crude oil - production"])
uk_crude_prod = choose_commodity (uk_crude, ["conventional crude oil - production"])
us_crude_prod = choose_commodity (us_crude, ["conventional crude oil - production"])
germany_crude_prod = choose_commodity (germany_crude, ["conventional crude oil - production"])
italy_crude_prod = choose_commodity (italy_crude, ["conventional crude oil - production"])
canada_crude_prod = choose_commodity (canada_crude, ["conventional crude oil - production"])

# %%
france_crude_prod
# Out:
#    country_or_area                commodity_transaction  year  \
# 0           france  conventional crude oil - production  1990
# 1           france  conventional crude oil - production  1991
# 2           france  conventional crude oil - production  1992
# 3           france  conventional crude oil - production  1993
# 4           france  conventional crude oil - production  1994
# 5           france  conventional crude oil - production  1995
# 6           france  conventional crude oil - production  1996
# 7           france  conventional crude oil - production  1997
# 8           france  conventional crude oil - production  1998
# 9           france  conventional crude oil - production  1999
# 10          france  conventional crude oil - production  2000
# 11          france  conventional crude oil - production  2001
# 12          france  conventional crude oil - production  2002
# 13          france  conventional crude oil - production  2003
# ...

# %%
plt.figure(figsize = (15, 10))

x1 = france_crude_prod.year
y1 = france_crude_prod.quantity
plt.plot (x1, y1, label = "France")

x2 = japan_crude_prod.year
y2 = japan_crude_prod.quantity
plt.plot (x2, y2, label = "Japan")


x3 = uk_crude_prod.year
y3 = uk_crude_prod.quantity
plt.plot (x3, y3, label = "United Kingdom")

x4 = us_crude_prod.year
y4 = us_crude_prod.quantity
plt.plot (x4, y4, label = "United States")

x5 = germany_crude_prod.year
y5 = germany_crude_prod.quantity
plt.plot (x5, y5, label = "Germany")

x6 = italy_crude_prod.year
y6 = italy_crude_prod.quantity
plt.plot (x6, y6, label = "Italy")

x7 = canada_crude_prod.year
y7 = canada_crude_prod.quantity
plt.plot (x7, y7, label = "Canada")

plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel ("Year")
plt.ylabel ("Conventional Crude Oil production- (Metric tons, Thousand)")
plt.title ("Crude oil production for G7 countries", fontweight ="bold")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### FROM THE PLOT VISUALIZATION, WE CAN SEE THAT 3 COUNTRIES HAVE VISIBLE TRENDS :  (UNITED STATES, UNITED KINGDOM AND CANADA). UNITED STATES SHOWS A JUMP IN CRUDE OIL PRODUCTION FROM 2009-2014, PRODUCING MORE THAN 400,000 METRIC TONS OF CRUDE. THE UNITED KINGDOM ALSO EXPERIENCES A JUMP IN PRODUCTION FROM 2009-2014, PRODUCING ABOUT 140,000 METRICTONS IN THE YEAR 2014.  CANADA SHOWS A DECLINE IN OIL PRODUCTION FROM THE LATE 1900'S TILL 2014.

# %% [markdown]
# # CRUDE OIL EXPORTS AMONG G7COUNTRIES

# %%
france_crude_export = choose_commodity (france_crude, ["conventional crude oil - exports"])
japan_crude_export = choose_commodity (japan_crude, ["conventional crude oil - exports"])
uk_crude_export = choose_commodity (uk_crude, ["conventional crude oil - exports"])
us_crude_export = choose_commodity (us_crude, ["conventional crude oil - exports"])
germany_crude_export = choose_commodity (germany_crude, ["conventional crude oil - exports"])
italy_crude_export = choose_commodity (italy_crude, ["conventional crude oil - exports"])
canada_crude_export = choose_commodity (canada_crude, ["conventional crude oil - exports"])

# %%
france_crude_export
# Out:
#   country_or_area             commodity_transaction  year  \
# 0          france  conventional crude oil - exports  2010
# 1          france  conventional crude oil - exports  2011
# 2          france  conventional crude oil - exports  2012
# 3          france  conventional crude oil - exports  2013
# 4          france  conventional crude oil - exports  2014
#
#                      unit  quantity                category
# 0  metric tons,  thousand       0.0  conventional_crude_oil
# 1  metric tons,  thousand     461.0  conventional_crude_oil
# 2  metric tons,  thousand     183.0  conventional_crude_oil
# 3  metric tons,  thousand      68.0  conventional_crude_oil
# 4  metric tons,  thousand      20.0  conventional_crude_oil

# %%
plt.figure(figsize = (15, 10))

x1 = france_crude_export.year
y1 = france_crude_export.quantity
plt.plot (x1, y1, label = "France")

x2 = japan_crude_export.year
y2 = japan_crude_export.quantity
plt.plot (x2, y2, label = "Japan")


x3 = uk_crude_export.year
y3 = uk_crude_export.quantity
plt.plot (x3, y3, label = "United Kingdom")

x4 = us_crude_export.year
y4 = us_crude_export.quantity
plt.plot (x4, y4, label = "United States")

x5 = germany_crude_export.year
y5 = germany_crude_export.quantity
plt.plot (x5, y5, label = "Germany")

x6 = italy_crude_export.year
y6 = italy_crude_export.quantity
plt.plot (x6, y6, label = "Italy")

x7 = canada_crude_export.year
y7 = canada_crude_export.quantity
plt.plot (x7, y7, label = "Canada")

plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel ("Year")
plt.ylabel ("Conventional Crude Oil exportation- (Metric tons, Thousand)")
plt.title ("Crude oil Exports for G7 countries", fontweight ="bold")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## FROM THE VISUALIZATION, CANADA SHOWS A RISE IN CRUDE OIL EXPORTATION, RANKING HIGHEST WITH ABOUT 120,000 METRICTONS OF EXPORT IN THE YEAR 2014. THE UNITED KINGDOM SHOWS A RECENT DECLINE IN CRUDE OIL EXPORTS AND THE UNITED STATES OF AMERICA IS HAVING A SLIGHT RISE IN EXPORTS.
#
# ### Additional research shows that most of the oil produced by canada is exported to the united states as they have enough oil to cater for their needs and do not need most of the oil produced, hence, a reason for the large export of crude.

# %% [markdown]
# # CRUDE OIL IMPORTS AMONG G7COUNTRIES

# %%
france_crude_import = choose_commodity (france_crude, ["conventional crude oil - imports"])
japan_crude_import= choose_commodity (japan_crude, ["conventional crude oil - imports"])
uk_crude_import = choose_commodity (uk_crude, ["conventional crude oil - imports"])
us_crude_import = choose_commodity (us_crude, ["conventional crude oil - imports"])
germany_crude_import = choose_commodity (germany_crude, ["conventional crude oil - imports"])
italy_crude_import = choose_commodity (italy_crude, ["conventional crude oil - imports"])
canada_crude_import = choose_commodity (canada_crude, ["conventional crude oil - imports"])

# %%
france_crude_import
# Out:
#    country_or_area             commodity_transaction  year  \
# 0           france  conventional crude oil - imports  1990
# 1           france  conventional crude oil - imports  1991
# 2           france  conventional crude oil - imports  1992
# 3           france  conventional crude oil - imports  1993
# 4           france  conventional crude oil - imports  1994
# 5           france  conventional crude oil - imports  1995
# 6           france  conventional crude oil - imports  1996
# 7           france  conventional crude oil - imports  1997
# 8           france  conventional crude oil - imports  1998
# 9           france  conventional crude oil - imports  1999
# 10          france  conventional crude oil - imports  2000
# 11          france  conventional crude oil - imports  2001
# 12          france  conventional crude oil - imports  2002
# 13          france  conventional crude oil - imports  2003
# 14          france  conventional crude oil - imports  2004
# ...

# %%
plt.figure(figsize = (15, 10))

x1 = france_crude_import.year
y1 = france_crude_import.quantity
plt.plot (x1, y1, label = "France")

x2 = japan_crude_import.year
y2 = japan_crude_import.quantity
plt.plot (x2, y2, label = "Japan")


x3 = uk_crude_import.year
y3 = uk_crude_import.quantity
plt.plot (x3, y3, label = "United Kingdom")

x4 = us_crude_import.year
y4 = us_crude_import.quantity
plt.plot (x4, y4, label = "United States")

x5 = germany_crude_import.year
y5 = germany_crude_import.quantity
plt.plot (x5, y5, label = "Germany")

x6 = italy_crude_import.year
y6 = italy_crude_import.quantity
plt.plot (x6, y6, label = "Italy")

x7 = canada_crude_import.year
y7 = canada_crude_import.quantity
plt.plot (x7, y7, label = "Canada")

plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel ("Year")
plt.ylabel ("Conventional Crude Oil Importation- (Metric tons, Thousand)")
plt.title ("Crude oil Imports for G7 countries", fontweight ="bold")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## THERE IS A VERY HIGH IMPORT RATE FROM THE UNITED STATES (HIGH POPULATION) AS SEEN FROM THE VISUALIZATION AND THIS IS DUE TO THE HIGH DEMAND FOR CRUDE OIL PRODUCTS FOR BOTH DOMESTIC USE AND REFINERIES COMPARED TO THE OTHER COUNTRIES. ALSO, LOOKING AT THE PRODUCTION AND IMPORT CURVES, AS IMPORT RATES IN THE UNITED STATES INCREASE, PRODUCTION REDUCES AND AS PRODUCTION INCREASES, IMPORT RATES REDUCE. JAPAN COMES SECOND IN IMPORTS RATE AND GERMANY COMES THIRD. CANADA SHOWS A STEADY IMPORTS RATE LINE, SHOWING THAT THEY PRODUCE ENOUGH FOR THEIR POPULACE.

# %% [markdown]
# # ELECTRICITY AMONG G7 COUNTRIES

# %%
france_electricity = choose_category (france_data,["total_electricity"])
japan_electricity = choose_category (japan_data,["total_electricity"])
uk_electricity = choose_category (uk_data,["total_electricity"])
us_electricity = choose_category (us_data,["total_electricity"])
germany_electricity = choose_category (germany_data,["total_electricity"])
italy_electricity = choose_category (italy_data,["total_electricity"])
canada_electricity = choose_category (canada_data,["total_electricity"])

# %%
france_electricity
# Out:
#      country_or_area                              commodity_transaction  year  \
# 0             france          electricity - consumption by construction  1990
# 1             france                       electricity - net production  1990
# 2             france                     electricity - gross production  1990
# 3             france                         electricity - gross demand  1990
# 4             france  electricity - consumption in agriculture, fore...  1990
# ...              ...                                                ...   ...
# 1413          france  electricity - own use by electricity, heat and...  2014
# 1414          france  electricity - consumption by paper, pulp and p...  2014
# 1415          france            electricity - own use by oil refineries  2014
# 1416          france    electricity - own use by oil and gas extraction  2014
# 1417          france                               hydro – autoproducer  2014
#
# ...

# %%
france_electricity_T = choose_commodity (france_electricity,["electricity - net production"])
japan_electricity_T = choose_commodity (japan_electricity,["electricity - net production"])
uk_electricity_T = choose_commodity (uk_electricity,["electricity - net production"])
us_electricity_T = choose_commodity (us_electricity,["electricity - net production"])
germany_electricity_T = choose_commodity (germany_electricity,["electricity - net production"])
italy_electricity_T = choose_commodity (italy_electricity,["electricity - net production"])
canada_electricity_T = choose_commodity (canada_electricity,["electricity - net production"])

# %%
france_electricity_T
# Out:
#    country_or_area         commodity_transaction  year  \
# 0           france  electricity - net production  1990
# 1           france  electricity - net production  1991
# 2           france  electricity - net production  1992
# 3           france  electricity - net production  1993
# 4           france  electricity - net production  1994
# 5           france  electricity - net production  1995
# 6           france  electricity - net production  1996
# 7           france  electricity - net production  1997
# 8           france  electricity - net production  1998
# 9           france  electricity - net production  1999
# 10          france  electricity - net production  2000
# 11          france  electricity - net production  2001
# 12          france  electricity - net production  2002
# 13          france  electricity - net production  2003
# 14          france  electricity - net production  2004
# 15          france  electricity - net production  2005
# ...

# %%
plt.figure(figsize = (15, 10))

x1 = france_electricity_T.year
y1 = france_electricity_T.quantity
plt.plot (x1, y1, label = "France")

x2 = japan_electricity_T.year
y2 = japan_electricity_T.quantity
plt.plot (x2, y2, label = "Japan")


x3 = uk_electricity_T.year
y3 = uk_electricity_T.quantity
plt.plot (x3, y3, label = "United Kingdom")

x4 = us_electricity_T.year
y4 = us_electricity_T.quantity
plt.plot (x4, y4, label = "United States")

x5 = germany_electricity_T.year
y5 = germany_electricity_T.quantity
plt.plot (x5, y5, label = "Germany")

x6 = italy_electricity_T.year
y6 = italy_electricity_T.quantity
plt.plot (x6, y6, label = "Italy")

x7 = canada_electricity_T.year
y7 = canada_electricity_T.quantity
plt.plot (x7, y7, label = "Canada")

plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel ("Year")
plt.ylabel ("Electricity Net Production- (Kilowatt-Hours, Million)")
plt.title ("Electricity Net Production for G7 countries", fontweight ="bold")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### THE UNITED STATES OF AMERICA IS THE LEADER AS RELATES NET ELECTRICITY PRODUCTION AMONG G7 COUNTRIES

# %% [markdown]
# # SOLAR ELECTRICITY AMONG G7 COUNTRIES

# %%
france_solar = choose_category (france_data,["solar_electricity"])
japan_solar = choose_category (japan_data,["solar_electricity"])
uk_solar = choose_category (uk_data,["solar_electricity"])
us_solar = choose_category (us_data,["solar_electricity"])
germany_solar = choose_category (germany_data,["solar_electricity"])
italy_solar = choose_category (italy_data,["solar_electricity"])
canada_solar = choose_category (canada_data,["solar_electricity"])

# %%
france_solar
# Out:
#    country_or_area                 commodity_transaction  year  \
# 0           france  electricity - total solar production  1994
# 1           france  electricity - total solar production  1995
# 2           france  electricity - total solar production  1996
# 3           france  electricity - total solar production  1997
# 4           france  electricity - total solar production  1998
# 5           france  electricity - total solar production  1999
# 6           france  electricity - total solar production  2000
# 7           france  electricity - total solar production  2001
# 8           france  electricity - total solar production  2002
# 9           france  electricity - total solar production  2003
# 10          france  electricity - total solar production  2004
# 11          france  electricity - total solar production  2005
# 12          france  electricity - total solar production  2006
# 13          france  electricity - total solar production  2007
# ...

# %%
france_electricity_S = choose_commodity (france_solar,["electricity - total solar production"])
japan_electricity_S = choose_commodity (japan_solar,["electricity - total solar production"])
uk_electricity_S = choose_commodity (uk_solar,["electricity - total solar production"])
us_electricity_S = choose_commodity (us_solar,["electricity - total solar production"])
germany_electricity_S = choose_commodity (germany_solar,["electricity - total solar production"])
italy_electricity_S = choose_commodity (italy_solar,["electricity - total solar production"])
canada_electricity_S = choose_commodity (canada_solar,["electricity - total solar production"])

# %%
france_electricity_S
# Out:
#    country_or_area                 commodity_transaction  year  \
# 0           france  electricity - total solar production  1994
# 1           france  electricity - total solar production  1995
# 2           france  electricity - total solar production  1996
# 3           france  electricity - total solar production  1997
# 4           france  electricity - total solar production  1998
# 5           france  electricity - total solar production  1999
# 6           france  electricity - total solar production  2000
# 7           france  electricity - total solar production  2001
# 8           france  electricity - total solar production  2002
# 9           france  electricity - total solar production  2003
# 10          france  electricity - total solar production  2004
# 11          france  electricity - total solar production  2005
# 12          france  electricity - total solar production  2006
# 13          france  electricity - total solar production  2007
# ...

# %%
plt.figure(figsize = (15, 10))

x1 = france_electricity_S.year
y1 = france_electricity_S.quantity
plt.plot (x1, y1, label = "France")

x2 = japan_electricity_S.year
y2 = japan_electricity_S.quantity
plt.plot (x2, y2, label = "Japan")


x3 = uk_electricity_S.year
y3 = uk_electricity_S.quantity
plt.plot (x3, y3, label = "United Kingdom")

x4 = us_electricity_S.year
y4 = us_electricity_S.quantity
plt.plot (x4, y4, label = "United States")

x5 = germany_electricity_S.year
y5 = germany_electricity_S.quantity
plt.plot (x5, y5, label = "Germany")

x6 = italy_electricity_S.year
y6 = italy_electricity_S.quantity
plt.plot (x6, y6, label = "Italy")

x7 = canada_electricity_S.year
y7 = canada_electricity_S.quantity
plt.plot (x7, y7, label = "Canada")

plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel ("Year")
plt.ylabel ("Electricity- Total Solar Production- (Kilowatt-Hours, Million)")
plt.title ("Public Solar Energy Installed for G7 countries", fontweight ="bold")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## GERMANY IS LEADING IN TOTAL SOLAR PRODUCTION AMONG THE G7 COUNTRIES WITH THE U.S ,JAPAN AND ITALY COMING AFTER. CANADA HAS THE LEAST PRODUCTION RATE.

# %% [markdown]
# ## CRUDE OIL PRODUCTION IN A7 (LEADING AFRICAN COUNTRIES) COUNTRIES
#
# #### 1.0 COUNTRY DATA CATEGORIZATION

# %%
A7
# Out:
#         country_or_area                              commodity_transaction  \
# 5056       South Africa  Anthracite - consumption by chemical and petro...
# 5057       South Africa  Anthracite - consumption by chemical and petro...
# 5058       South Africa  Anthracite - consumption by chemical and petro...
# 5059       South Africa  Anthracite - consumption by chemical and petro...
# 5349       South Africa         Anthracite - consumption by iron and steel
# ...                 ...                                                ...
# 1189224    South Africa                Electricity - total wind production
# 1189225    South Africa                Electricity - total wind production
# 1189226    South Africa                Electricity - total wind production
# 1189227    South Africa                Electricity - total wind production
# 1189228    South Africa                Electricity - total wind production
#
# ...

# %%
DROP_A7 = A7.drop(["quantity_footnotes"], axis = 1)

# %%
DROP_A7.country_or_area = DROP_A7.country_or_area.str.lower()
DROP_A7.commodity_transaction = DROP_A7.commodity_transaction.str.lower()
DROP_A7.unit = DROP_A7.unit.str.lower()
DROP_A7.category = DROP_A7.category.str.lower()

# %%
def choose_country (country_name):
    country_data = DROP_A7[DROP_A7.country_or_area.isin(country_name)].sort_values("year").reset_index()
    country_data.drop ('index', axis=1 , inplace = True)
    return  country_data

# %%
nigeria_data = choose_country (["nigeria"])
southafrica_data = choose_country (["south africa"])
angola_data = choose_country (["angola"])
morocco_data = choose_country (["morocco"])
egypt_data = choose_country (["egypt"])
ethopia_data = choose_country (["ethopia"])
kenya_data = choose_country (["kenya"])

# %%
nigeria_data
# Out:
#      country_or_area                              commodity_transaction  year  \
# 0            nigeria                          total refinery throughput  1990
# 1            nigeria                          fuelwood - transformation  1990
# 2            nigeria                   natural gas liquids - production  1990
# 3            nigeria                           motor gasoline - exports  1990
# 4            nigeria                             hard coal - production  1990
# ...              ...                                                ...   ...
# 5512         nigeria  gas oil/ diesel oil - consumption by construct...  2014
# 5513         nigeria                           motor gasoline - imports  2014
# 5514         nigeria                 refinery gas - total energy supply  2014
# 5515         nigeria                             hard coal - production  2014
# 5516         nigeria  bagasse - consumption by manufacturing, constr...  2014
#
# ...

# %% [markdown]
# #### 2.0 CRUDE OIL DATA CATEGORIZATION BASED ON COUNTRY

# %%
def choose_category (country_data, category_name):
    category_data = country_data[country_data.category.isin(category_name)].sort_values("year").reset_index()
    category_data.drop ('index', axis=1 , inplace = True)
    return  category_data

# %%
nigeria_crude = choose_category (nigeria_data,["conventional_crude_oil"])
southafrica_crude = choose_category (southafrica_data,["conventional_crude_oil"])
angola_crude = choose_category (angola_data,["conventional_crude_oil"])
morocco_crude = choose_category (morocco_data,["conventional_crude_oil"])
egypt_crude = choose_category (egypt_data,["conventional_crude_oil"])
ethopia_crude = choose_category (ethopia_data,["conventional_crude_oil"])
kenya_crude = choose_category (kenya_data,["conventional_crude_oil"])

# %%
nigeria_crude
# Out:
#     country_or_area                              commodity_transaction  year  \
# 0           nigeria  conventional crude oil - production from off-s...  1990
# 1           nigeria                conventional crude oil - production  1990
# 2           nigeria                   conventional crude oil - exports  1990
# 3           nigeria  conventional crude oil - transformation in oil...  1990
# 4           nigeria                crude petroleum - refinery capacity  1990
# ..              ...                                                ...   ...
# 212         nigeria       conventional crude oil - total energy supply  2014
# 213         nigeria                         crude petroleum - reserves  2014
# 214         nigeria                crude petroleum - refinery capacity  2014
# 215         nigeria            conventional crude oil - transformation  2014
# 216         nigeria                conventional crude oil - production  2014
#
# ...

# %%
nigeria_crude_prod = choose_commodity (nigeria_crude, ["conventional crude oil - production"])
southafrica_crude_prod = choose_commodity (southafrica_crude, ["conventional crude oil - production"])
angola_crude_prod = choose_commodity (angola_crude, ["conventional crude oil - production"])
morocco_crude_prod = choose_commodity (morocco_crude, ["conventional crude oil - production"])
egypt_crude_prod = choose_commodity (egypt_crude, ["conventional crude oil - production"])
ethopia_crude_prod = choose_commodity (ethopia_crude, ["conventional crude oil - production"])
kenya_crude_prod = choose_commodity (kenya_crude, ["conventional crude oil - production"])

# %%
nigeria_crude_prod
# Out:
#    country_or_area                commodity_transaction  year  \
# 0          nigeria  conventional crude oil - production  1990
# 1          nigeria  conventional crude oil - production  1991
# 2          nigeria  conventional crude oil - production  1992
# 3          nigeria  conventional crude oil - production  1993
# 4          nigeria  conventional crude oil - production  1994
# 5          nigeria  conventional crude oil - production  1995
# 6          nigeria  conventional crude oil - production  1996
# 7          nigeria  conventional crude oil - production  1997
# 8          nigeria  conventional crude oil - production  1998
# 9          nigeria  conventional crude oil - production  1999
# 10         nigeria  conventional crude oil - production  2000
# 11         nigeria  conventional crude oil - production  2001
# 12         nigeria  conventional crude oil - production  2002
# 13         nigeria  conventional crude oil - production  2003
# ...

# %%
plt.figure(figsize = (15, 10))

x1 = nigeria_crude_prod.year
y1 = nigeria_crude_prod.quantity
plt.plot (x1, y1, label = "Nigeria")

x2 = southafrica_crude_prod.year
y2 = southafrica_crude_prod.quantity
plt.plot (x2, y2, label = "Southafrica")


x3 = angola_crude_prod.year
y3 = angola_crude_prod.quantity
plt.plot (x3, y3, label = "Angola")

x4 = morocco_crude_prod.year
y4 = morocco_crude_prod.quantity
plt.plot (x4, y4, label = "Morocco")

x5 = egypt_crude_prod.year
y5 = egypt_crude_prod.quantity
plt.plot (x5, y5, label = "Egypt")

x6 = ethopia_crude_prod.year
y6 = ethopia_crude_prod.quantity
plt.plot (x6, y6, label = "Ethiopia")

x7 = kenya_crude_prod.year
y7 = kenya_crude_prod.quantity
plt.plot (x7, y7, label = "Kenya")

plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel ("Year")
plt.ylabel ("Conventional Crude Oil production- (Metric tons, Thousand)")
plt.title ("Crude oil production for A7 countries", fontweight ="bold")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## FROM THE VISUALIZATION WE CAN SEE A "NOT-SO-STEADY" PRODUCTION OF CRUDE OIL IN NIGERIA STILL ON THE LEAD AND ANGOLA ON THE RISE FROM 2001-2007 BEFORE A DROP AND EGYPT COMING THIRD. THE REMAINING AFRICAN COUNTRIES ARE NOT CRUDE-OIL PRODUCERS.

# %% [markdown]
# ## CRUDE OIL EXPORTS AMONG A7 COUNTRIES

# %%
nigeria_crude_export = choose_commodity (nigeria_crude, ["conventional crude oil - exports"])
southafrica_crude_export = choose_commodity (southafrica_crude, ["conventional crude oil - exports"])
angola_crude_export = choose_commodity (angola_crude, ["conventional crude oil - exports"])
morocco_crude_export = choose_commodity (morocco_crude, ["conventional crude oil - exports"])
egypt_crude_export = choose_commodity (egypt_crude, ["conventional crude oil - exports"])
ethopia_crude_export = choose_commodity (ethopia_crude, ["conventional crude oil - exports"])
kenya_crude_export = choose_commodity (kenya_crude, ["conventional crude oil - exports"])

# %%
nigeria_crude_export
# Out:
#    country_or_area             commodity_transaction  year  \
# 0          nigeria  conventional crude oil - exports  1990
# 1          nigeria  conventional crude oil - exports  1991
# 2          nigeria  conventional crude oil - exports  1992
# 3          nigeria  conventional crude oil - exports  1993
# 4          nigeria  conventional crude oil - exports  1994
# 5          nigeria  conventional crude oil - exports  1995
# 6          nigeria  conventional crude oil - exports  1996
# 7          nigeria  conventional crude oil - exports  1997
# 8          nigeria  conventional crude oil - exports  1998
# 9          nigeria  conventional crude oil - exports  1999
# 10         nigeria  conventional crude oil - exports  2000
# 11         nigeria  conventional crude oil - exports  2001
# 12         nigeria  conventional crude oil - exports  2002
# 13         nigeria  conventional crude oil - exports  2003
# 14         nigeria  conventional crude oil - exports  2004
# ...

# %%
plt.figure(figsize = (15, 10))
x1 = nigeria_crude_export.year
y1 = nigeria_crude_export.quantity
plt.plot (x1, y1, label = "Nigeria")

x2 = southafrica_crude_export.year
y2 = southafrica_crude_export.quantity
plt.plot (x2, y2, label = "South africa")


x3 = angola_crude_export.year
y3 = angola_crude_export.quantity
plt.plot (x3, y3, label = "Angola")

x4 = morocco_crude_export.year
y4 = morocco_crude_export.quantity
plt.plot (x4, y4, label = "Morocco")

x5 = egypt_crude_export.year
y5 = egypt_crude_export.quantity
plt.plot (x5, y5, label = "Egypt")

x6 = ethopia_crude_export.year
y6 = ethopia_crude_export.quantity
plt.plot (x6, y6, label = "Ethiopia")

x7 = kenya_crude_export.year
y7 = kenya_crude_export.quantity
plt.plot (x7, y7, label = "Kenya")

plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel ("Year")
plt.ylabel ("Conventional Crude Oil exportation- (Metric tons, Thousand)")
plt.title ("Crude oil Exports for A7 countries", fontweight ="bold")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### FROM THE VISUALIZATION WE CAN SEE A "NOT-SO-STEADY" EXPORTATION OF CRUDE OIL IN NIGERIA STILL ON THE LEAD AND ANGOLA ON THE RISE FROM 2001-2007 BEFORE A DROP AND EGYPT COMING THIRD. THE REMAINING AFRICAN COUNTRIES ARE NOT CRUDE-OIL PRODUCERS.

# %% [markdown]
# ## CRUDE OIL IMPORTS AMONG A7 COUNTRIES

# %%
nigeria_crude_import = choose_commodity (nigeria_crude, ["conventional crude oil - imports"])
southafrica_crude_import= choose_commodity (southafrica_crude, ["conventional crude oil - imports"])
angola_crude_import = choose_commodity (angola_crude, ["conventional crude oil - imports"])
morocco_crude_import = choose_commodity (morocco_crude, ["conventional crude oil - imports"])
egypt_crude_import = choose_commodity (egypt_crude, ["conventional crude oil - imports"])
ethiopia_crude_import = choose_commodity (ethopia_crude, ["conventional crude oil - imports"])
kenya_crude_import = choose_commodity (kenya_crude, ["conventional crude oil - imports"])

# %%
nigeria_crude_import
# Out:
# Empty DataFrame
# Columns: [country_or_area, commodity_transaction, year, unit, quantity, category]
# Index: []

# %%
southafrica_crude_import
# Out:
#    country_or_area             commodity_transaction  year  \
# 0     south africa  conventional crude oil - imports  1990
# 1     south africa  conventional crude oil - imports  1991
# 2     south africa  conventional crude oil - imports  1992
# 3     south africa  conventional crude oil - imports  1993
# 4     south africa  conventional crude oil - imports  1994
# 5     south africa  conventional crude oil - imports  1995
# 6     south africa  conventional crude oil - imports  1996
# 7     south africa  conventional crude oil - imports  1997
# 8     south africa  conventional crude oil - imports  1998
# 9     south africa  conventional crude oil - imports  1999
# 10    south africa  conventional crude oil - imports  2000
# 11    south africa  conventional crude oil - imports  2001
# 12    south africa  conventional crude oil - imports  2002
# 13    south africa  conventional crude oil - imports  2003
# 14    south africa  conventional crude oil - imports  2004
# ...

# %%
nigeria_crude[nigeria_crude.commodity_transaction.str.contains("conventional crude oil - imports")] ###THIS DATASET STATES THERE IS NO RECORD FOR CRUDE IMPORTATION FROM NIGERIA
# Out:
# Empty DataFrame
# Columns: [country_or_area, commodity_transaction, year, unit, quantity, category]
# Index: []

# %%
plt.figure(figsize = (15, 10))

x1 = nigeria_crude_import.year
y1 = nigeria_crude_import.quantity
plt.plot (x1, y1, label = "Nigeria")

x2 = southafrica_crude_import.year
y2 = southafrica_crude_import.quantity
plt.plot (x2, y2, label = "South Africa")


x3 = angola_crude_import.year
y3 = angola_crude_import.quantity
plt.plot (x3, y3, label = "Angola")

x4 = morocco_crude_import.year
y4 = morocco_crude_import.quantity
plt.plot (x4, y4, label = "Morocco")

x5 = egypt_crude_import.year
y5 = egypt_crude_import.quantity
plt.plot (x5, y5, label = "Egypt")

x6 = ethiopia_crude_import.year
y6 = ethiopia_crude_import.quantity
plt.plot (x6, y6, label = "Ethiopia")

x7 = kenya_crude_import.year
y7 = kenya_crude_import.quantity
plt.plot (x7, y7, label = "Kenya")

plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel ("Year")
plt.ylabel ("Conventional Crude Oil Importation- (Metric tons, Thousand)")
plt.title ("Crude oil Imports for A7 countries", fontweight ="bold")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## SOUTH AFRICA LEADS WITH CRUDE OIL IMPORTATION, FOLLOWED BY MOROCCO AND EGYPT

# %% [markdown]
# ## ELECTRICITY AMONG A7 COUNTRIES

# %%
nigeria_electricity = choose_category (nigeria_data,["total_electricity"])
southafrica_electricity = choose_category (southafrica_data,["total_electricity"])
angola_electricity = choose_category (angola_data,["total_electricity"])
morocco_electricity = choose_category (morocco_data,["total_electricity"])
egypt_electricity = choose_category (egypt_data,["total_electricity"])
ethiopia_electricity = choose_category (ethopia_data,["total_electricity"])
kenya_electricity = choose_category (kenya_data,["total_electricity"])

# %%
nigeria_electricity
# Out:
#     country_or_area                              commodity_transaction  year  \
# 0           nigeria  electricity - own use by electricity, heat and...  1990
# 1           nigeria             from combustible fuels – main activity  1990
# 2           nigeria                               hydro – autoproducer  1990
# 3           nigeria                              hydro – main activity  1990
# 4           nigeria  from combustible fuels – main activity – elect...  1990
# ..              ...                                                ...   ...
# 520         nigeria                              hydro – main activity  2014
# 521         nigeria  from combustible fuels – main activity – elect...  2014
# 522         nigeria  electricity - consumption by commercial and pu...  2014
# 523         nigeria                         electricity - gross demand  2014
# 524         nigeria      electricity - total production, main activity  2014
#
# ...

# %%
nigeria_electricity_T = choose_commodity (nigeria_electricity,["electricity - net production"])
southafrica_electricity_T = choose_commodity (southafrica_electricity,["electricity - net production"])
angola_electricity_T = choose_commodity (angola_electricity,["electricity - net production"])
morocco_electricity_T = choose_commodity (morocco_electricity,["electricity - net production"])
egypt_electricity_T = choose_commodity (egypt_electricity,["electricity - net production"])
ethiopia_electricity_T = choose_commodity (ethiopia_electricity,["electricity - net production"])
kenya_electricity_T = choose_commodity (kenya_electricity,["electricity - net production"])

# %%
nigeria_electricity_T
# Out:
#    country_or_area         commodity_transaction  year  \
# 0          nigeria  electricity - net production  1990
# 1          nigeria  electricity - net production  1991
# 2          nigeria  electricity - net production  1992
# 3          nigeria  electricity - net production  1993
# 4          nigeria  electricity - net production  1994
# 5          nigeria  electricity - net production  1995
# 6          nigeria  electricity - net production  1996
# 7          nigeria  electricity - net production  1997
# 8          nigeria  electricity - net production  1998
# 9          nigeria  electricity - net production  1999
# 10         nigeria  electricity - net production  2000
# 11         nigeria  electricity - net production  2001
# 12         nigeria  electricity - net production  2002
# 13         nigeria  electricity - net production  2003
# 14         nigeria  electricity - net production  2004
# 15         nigeria  electricity - net production  2005
# ...

# %%
plt.figure(figsize = (15, 10))

x1 = nigeria_electricity_T.year
y1 = nigeria_electricity_T.quantity
plt.plot (x1, y1, label = "Nigeria")

x2 = southafrica_electricity_T.year
y2 = southafrica_electricity_T.quantity
plt.plot (x2, y2, label = "South Africa")


x3 = angola_electricity_T.year
y3 = angola_electricity_T.quantity
plt.plot (x3, y3, label = "Angola")

x4 = morocco_electricity_T.year
y4 = morocco_electricity_T.quantity
plt.plot (x4, y4, label = "Morocco")

x5 = egypt_electricity_T.year
y5 = egypt_electricity_T.quantity
plt.plot (x5, y5, label = "Egypt")

x6 = ethiopia_electricity_T.year
y6 = ethiopia_electricity_T.quantity
plt.plot (x6, y6, label = "Ethiopia")

x7 = kenya_electricity_T.year
y7 = kenya_electricity_T.quantity
plt.plot (x7, y7, label = "Kenya")

plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel ("Year")
plt.ylabel ("Electricity Net Production- (Kilowatt-Hours, Million)")
plt.title ("Electricity Net Production for A7 countries", fontweight ="bold")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### SOUTH AFRICA IS LEADING IN THE AREA OF ELECTRICITY NET PRODUCTION AND EGYPT COMES IN  SECOND. NIGERIA AND MOROCCO ARE THIRD.

# %%
nigeria_solar = choose_category (nigeria_data,["solar_electricity"])
southafrica_solar = choose_category (southafrica_data,["solar_electricity"])
angola_solar = choose_category (angola_data,["solar_electricity"])
morocco_solar = choose_category (morocco_data,["solar_electricity"])
egypt_solar = choose_category (egypt_data,["solar_electricity"])
ethiopia_solar = choose_category (ethopia_data,["solar_electricity"])
kenya_solar = choose_category (kenya_data,["solar_electricity"])

# %%
nigeria_solar
# Out:
# Empty DataFrame
# Columns: [country_or_area, commodity_transaction, year, unit, quantity, category]
# Index: []

# %%
nigeria_electricity_S = choose_commodity (nigeria_solar,["electricity - total solar production"])
southafrica_electricity_S = choose_commodity (southafrica_solar,["electricity - total solar production"])
angola_electricity_S = choose_commodity (angola_solar,["electricity - total solar production"])
morocco_electricity_S = choose_commodity (morocco_solar,["electricity - total solar production"])
egypt_electricity_S = choose_commodity (egypt_solar,["electricity - total solar production"])
ethiopia_electricity_S = choose_commodity (ethiopia_solar,["electricity - total solar production"])
kenya_electricity_S = choose_commodity (kenya_solar,["electricity - total solar production"])

# %%
nigeria_electricity_S
# Out:
# Empty DataFrame
# Columns: [country_or_area, commodity_transaction, year, unit, quantity, category]
# Index: []

# %%
plt.figure(figsize = (15, 10))

x1 = nigeria_electricity_S.year
y1 = nigeria_electricity_S.quantity
plt.plot (x1, y1, label = "Nigeria")

x2 = southafrica_electricity_S.year
y2 = southafrica_electricity_S.quantity
plt.plot (x2, y2, label = "South Africa")


x3 = angola_electricity_S.year
y3 = angola_electricity_S.quantity
plt.plot (x3, y3, label = "Angola")

x4 = morocco_electricity_S.year
y4 = morocco_electricity_S.quantity
plt.plot (x4, y4, label = "Morocco")

x5 = egypt_electricity_S.year
y5 = egypt_electricity_S.quantity
plt.plot (x5, y5, label = "Egypt")

x6 = italy_electricity_S.year
y6 = italy_electricity_S.quantity
plt.plot (x6, y6, label = "Ethiopia")

x7 = canada_electricity_S.year
y7 = canada_electricity_S.quantity
plt.plot (x7, y7, label = "Kenya")

plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel ("Year")
plt.ylabel ("Electricity- Total Solar Production- (Kilowatt-Hours, Million)")
plt.title ("Public Solar Energy Installed for A7 countries", fontweight ="bold")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### ETHIOPIA IS CLEAR AMONG ALL OTHER AFRICAN COUNTRIES IN THE PRODUCTION OF SOLAR WITH MORE THAN 20000 MILLION KILOWATT-HOURS. IT IS CLEARLY SEEN THAT AFRICAN COUNTRIES WERE NOT YET INVESTING IN SOLAR PRODUCTION AS AT 2014
